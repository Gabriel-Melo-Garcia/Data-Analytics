# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd

# %%
# amazon_url = 'https://www.amazon.com/s?k=laptop&crid=IV9CRTOGNGQK&sprefix=laptop%2Caps%2C262&ref=nb_sb_noss_1'
# amazon_url2 = 'https://www.amazon.com/s?k=laptop'
amazon_url3 = 'https://www.amazon.com/s?k=laptop&page=2'
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
}

response = requests.get(amazon_url3,headers=HEADERS)
#html = response.text

soup = BeautifulSoup(response.content, "html.parser")

soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
# lista = soup.find_all(class_="puis-card-container s-card-container s-overflow-hidden aok-relative puis-include-content-margin puis puis-v1ykctib3w9wx42mv5famb0xfqm s-latency-cf-section puis-card-border")
list_items = soup.find_all('div', attrs={'role': 'listitem'})

# %%
# elemento = lista[3]
# teste = elemento.select_one("div > div > div.puisg-col.puisg-col-4-of-12.puisg-col-8-of-16.puisg-col-12-of-20.puisg-col-12-of-24.puis-list-col-right > div > div > div:nth-child(3) > div.puisg-col.puisg-col-4-of-12.puisg-col-4-of-16.puisg-col-4-of-20.puisg-col-4-of-24 > div > div.a-section.a-spacing-none.a-spacing-top-micro.puis-price-instructions-style > div > div:nth-child(1) > a > span > span.a-offscreen")
# teste

# %%
resultados = []
for item in list_items:
    
    preco = item.select_one(
            "div > div > div.puisg-col.puisg-col-4-of-12.puisg-col-8-of-16.puisg-col-12-of-20.puisg-col-12-of-24.puis-list-col-right > div > div > div:nth-child(3) > div.puisg-col.puisg-col-4-of-12.puisg-col-4-of-16.puisg-col-4-of-20.puisg-col-4-of-24 > div > div.a-section.a-spacing-none.a-spacing-top-micro.puis-price-instructions-style > div > div:nth-child(1) > a > span > span.a-offscreen"
        )
    preco_texto = preco.text.strip() if preco else None
    # Capturando o nome
    nome = item.select_one(
            "div > div > span > div > div > div > div.puisg-col.puisg-col-4-of-12.puisg-col-8-of-16.puisg-col-12-of-20.puisg-col-12-of-24.puis-list-col-right > div > div > div.a-section.a-spacing-none.puis-padding-right-small.s-title-instructions-style > a > h2"
    )
    nome_texto = nome.text.strip() if nome else None

    # Capturando o número de reviews
    reviews = item.select_one(
            "div > div > div > div > span > div > div > div > div.puisg-col.puisg-col-4-of-12.puisg-col-8-of-16.puisg-col-12-of-20.puisg-col-12-of-24.puis-list-col-right > div > div > div.a-section.a-spacing-none.a-spacing-top-micro > div.a-row.a-size-small > span.rush-component > div > a > span"
    )
    reviews_texto = reviews.text.strip() if reviews else None

    # Capturando a nota
    nota = item.select_one(
            "div > div > div > div > span > div > div > div > div.puisg-col.puisg-col-4-of-12.puisg-col-8-of-16.puisg-col-12-of-20.puisg-col-12-of-24.puis-list-col-right > div > div > div.a-section.a-spacing-none.a-spacing-top-micro > div.a-row.a-size-small > span.a-declarative > a"
    )
    nota_texto = nota.text.strip() if nota else None

  
    if nome_texto != None:
        resultados.append({
                "nome": nome_texto,
                "preco": preco_texto,
                "reviews": reviews_texto,
                "nota": nota_texto
        })
    
    # Exibindo os resultados
if resultados:
    print("Elementos encontrados:")
    print(resultados)
else:
    print("Nenhum elemento encontrado!")
# Out:
# Elementos encontrados:
# ...

# %%
df = pd.DataFrame.from_dict(resultados)
df
# Out:
#                                                  nome      preco reviews  \
# 0   Laptops, 15.6" Laptops Computer, High Performa...    $169.99       4
# 1   jumper Laptop, Office 365 One-Year, 12GB RAM 5...    $529.99       7
# 2   ASUS E410 Intel Celeron N4020 4GB 64GB 14-Inch...       None     728
# 3   HP Notebook Laptop, 15.6" HD Touchscreen, Inte...    $421.97   1,107
# 4   HP 15.6" Portable Laptop (Include 1 Year Micro...       None     824
# 5   ASUS ROG Strix G16 (2024) Gaming Laptop, 16” 1...  $1,331.30   1,588
# 6   HP Pavilion 15.6" HD Touchscreen Anti-Glare La...    $396.94     804
# 7   Gaming Laptop, 2024 Laptop Computer with Intel...       None      10
# 8   Microsoft Surface Laptop (2024), Windows 11 Co...    $869.00     204
# 9   HP Victus 15.6 i5 Gaming Laptop, 15.6" FHD 192...    $620.00      86
# 10  Laptop Monitor Extender, Laptop Screen Extende...    $198.90     125
# 11  jumper Laptop, 4GB RAM 320GB Storage, Office 3...       None      50
# ...

# %%
if response.status_code == 200:
    # Criando o objeto BeautifulSoup
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Encontrando todas as divs com role="listitem"
    list_items = soup.find_all('div', attrs={'role': 'listitem'})
    
    # Convertendo as informações para uma lista (exemplo: ids ou dados)
    itens = []
    for item in list_items:
        # Pegando o atributo data-asin ou o texto interno, por exemplo
        asin = item.get('data-asin', 'N/A')  # Default: 'N/A' se não tiver data-asin
        itens.append(asin)
    
    # Mostrando o resultado
    print("Itens encontrados:")
    for i, item in enumerate(itens, start=1):
        print(f"{i}: {item}")
else:
    print(f"Erro ao acessar a página. Status code: {response.status_code}")
# Out:
# Itens encontrados:
# 1: B0DM1WJC11
# 2: B0DFLQFN9D
# 3: B09YRY6QCX
# 4: B0BZ8X9HGT
# 5: B0CPGKT77T
# 6: B0CRDCXRK2
# 7: B0C4G4L53W
# 8: B0DP2D4J45
# 9: B0CXKYTQS2
# 10: B0D845LL5R
# 11: B0D4L3YQJS
# 12: B0DGX4KMCK
# 13: B07RJZMC49
# 14: B0DPQGNLXW
# 15: B0B4Y6V2DB
# 16: B0DJD3FN16
# 17: B0DN1MNBPK
# 18: B08KSKH9MJ
# 19: B0DJNGM1PZ
# 20: B0CRD6PJDF
# 21: B0D22P4PTP
# 22: B0DR86VZLG
# 23: N/A
# 24: N/A
# 25: N/A
# 26: N/A
# 27: N/A
# 28: N/A
